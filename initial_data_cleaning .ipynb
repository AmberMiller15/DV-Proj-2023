# %%
import pandas as pd

# %%
#Create paths for data sources
full_accident_data = "Vehicle_data/accident.csv"
full_vehicle_data = "Vehicle_data/vehicle.csv"

#Read data sources
accident_df = pd.read_csv(full_accident_data)
vehicle_df = pd.read_csv(full_vehicle_data,encoding='ISO-8859-1')

# %%
#Drop unnecessary columns 
accident_df = accident_df.drop(columns=[
    "URBANICITY",
    "MONTH",
    "YEARNAME",
    "DAY_WEEK",
    "HOURNAME",
    "MINUTENAME",
    "HARM_EV",
    "ALCOHOL",
    "MAX_SEV",
    "MAN_COLL",
    "RELJCT2",
    "TYP_INT",
    "WRK_ZONE",
    "REL_ROAD",
    "LGT_COND",
    "WEATHER1",
    "WEATHER2",
    "WEATHER",
    "SCH_BUS",
    "INT_HWY",
    "CF1",
    "CF2",
    "CF3",
    "WKDY_IM",
    "HOUR_IM",
    "MINUTE_IMNAME",
    "EVENT1_IM",
    "MANCOL_IM",
    "RELJCT2_IM",
    "LGTCON_IM",
    "WEATHR_IM",
    "MAXSEV_IM",
    "NO_INJ_IM",
    "ALCHL_IM"
])

# %%
vehicle_df = vehicle_df.drop(columns=[
    "REGION",
    "URBANICITY",
    "MONTH",
    "HOUR",
    "HARM_EV",
    "MAN_COLL",
    "UNITTYPE",
    "HIT_RUN",
    "MAKE",
    "BODY_TYP",
    "MOD_YEAR",
    "VIN",
    "VINNAME",
    "TOW_VEH",
    "J_KNIFE",
    "MCARR_I1",
    "MCARR_I2",
    "MCARR_ID",
    "GVWR",
    "V_Config",
    "CARGO_BT",
    "HAZ_INV",
    "HAZ_PLAC",
    "HAZ_ID",
    "HAZ_CNO",
    "HAZ_REL",
    "BUS_USE",
    "SPEC_USE",
    "EMER_USE",
    "TRAV_SP",
    "ROLLOVER",
    "ROLINLOC",
    "IMPACT1",
    "DEFORMED",
    "TOWED",
    "M_HARM",
    "VEH_ALCH",
    "MAX_VSEV",
    "NUM_INJV",
    "VEH_SC1",
    "VEH_SC2",
    "FIRE_EXP",
    "DR_PRES",
    "DR_ZIP",
    "SPEEDREL",
    "DR_SF1",
    "DR_SF2",
    "DR_SF3",
    "DR_SF4",
    "VTRAFWAY",
    "VNUM_LAN",
    "VSPD_LIM",
    "VALIGN",
    "VPROFILE",
    "VSURCOND",
    "VTRAFCON",
    "VTCONT_F",
    "P_CRASH1",
    "P_CRASH2",
    "P_CRASH3",
    "PCRASH4",
    "PCRASH5",
    "ACC_TYPE",
    "TRLR1VIN",
    "TRLR2VIN",
    "TRLR3VIN",
    "PSUSTRAT",
    "HITRUN_IM",
    "BDYTYP_IM",
    "MDLYR_IM",
    "IMPACT1_IM",
    "VEVENT_IM",
    "PCRASH1_IM",
    "MXVSEV_IM",
    "NUMINJ_IM",
    "V_ALCH_IM"
])

# %%
list(accident_df.columns)
# Out:
# ['CASENUM',
#  'STRATUM',
#  'STRATUMNAME',
#  'REGION',
#  'REGIONNAME',
#  'PSU',
#  'PJ',
#  'PSU_VAR',
#  'URBANICITYNAME',
#  'VE_TOTAL',
#  'VE_FORMS',
#  'PVH_INVL',
#  'PEDS',
#  'PERMVIT',
#  'PERNOTMVIT',
#  'NUM_INJ',
#  'NUM_INJNAME',
#  'MONTHNAME',
#  'YEAR',
#  'DAY_WEEKNAME',
#  'HOUR',
#  'MINUTE',
#  'HARM_EVNAME',
#  'ALCOHOLNAME',
#  'MAX_SEVNAME',
#  'MAN_COLLNAME',
#  'RELJCT1',
#  'RELJCT1NAME',
#  'RELJCT2NAME',
#  'TYP_INTNAME',
#  'WRK_ZONENAME',
#  'REL_ROADNAME',
#  'LGT_CONDNAME',
#  'WEATHER1NAME',
#  'WEATHER2NAME',
#  'WEATHERNAME',
#  'SCH_BUSNAME',
#  'INT_HWYNAME',
#  'CF1NAME',
#  'CF2NAME',
#  'CF3NAME',
#  'PSUSTRAT',
#  'WEIGHT',
#  'WKDY_IMNAME',
#  'HOUR_IMNAME',
#  'MINUTE_IM',
#  'EVENT1_IMNAME',
#  'MANCOL_IMNAME',
#  'RELJCT2_IMNAME',
#  'LGTCON_IMNAME',
#  'WEATHR_IMNAME',
#  'MAXSEV_IMNAME',
#  'NO_INJ_IMNAME',
#  'ALCHL_IMNAME']

# %%
list(vehicle_df.columns)
# Out:
# ['CASENUM',
#  'VEH_NO',
#  'STRATUM',
#  'STRATUMNAME',
#  'REGIONNAME',
#  'PSU',
#  'PJ',
#  'PSU_VAR',
#  'URBANICITYNAME',
#  'VE_FORMS',
#  'NUMOCCS',
#  'NUMOCCSNAME',
#  'MONTHNAME',
#  'HOURNAME',
#  'MINUTE',
#  'MINUTENAME',
#  'HARM_EVNAME',
#  'MAN_COLLNAME',
#  'UNITTYPENAME',
#  'HIT_RUNNAME',
#  'MAKENAME',
#  'MODEL',
#  'MAK_MOD',
#  'MAK_MODNAME',
#  'BODY_TYPNAME',
#  'MOD_YEARNAME',
#  'TOW_VEHNAME',
#  'J_KNIFENAME',
#  'MCARR_I1NAME',
#  'MCARR_I2NAME',
#  'MCARR_IDNAME',
#  'GVWRNAME',
#  'V_ConfigNAME',
#  'CARGO_BTNAME',
#  'HAZ_INVNAME',
#  'HAZ_PLACNAME',
#  'HAZ_IDNAME',
#  'HAZ_CNONAME',
#  'HAZ_RELNAME',
#  'BUS_USENAME',
#  'SPEC_USENAME',
#  'EMER_USENAME',
#  'TRAV_SPNAME',
#  'ROLLOVERNAME',
#  'ROLINLOCNAME',
#  'IMPACT1NAME',
#  'DEFORMEDNAME',
#  'TOWEDNAME',
#  'M_HARMNAME',
#  'VEH_ALCHNAME',
#  'MAX_VSEVNAME',
#  'NUM_INJVNAME',
#  'VEH_SC1NAME',
#  'VEH_SC2NAME',
#  'FIRE_EXPNAME',
#  'DR_PRESNAME',
#  'DR_ZIPNAME',
#  'SPEEDRELNAME',
# ...

# %%
#Output data files
accident_df.to_csv("accident_clean.csv")
vehicle_df.to_csv("vehicle_clean.csv")
